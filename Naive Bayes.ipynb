# %%
import pandas as pd
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # Creat a little Dataset for first test and gain time

# %%
df_train = pd.read_csv('./data/fashion-mnist_train.csv')

# %%
label_tain = df_train['label']
data_train = df_train.drop('label', axis=1)

# %%
label_tain = label_tain[:len(label_tain)]

# %%
data_train = data_train[:len(data_train)]

# %%
label_tain.shape
# Out:
# (60000,)

# %%
data_train.shape
# Out:
# (60000, 784)

# %%
train_set, test_set, train_labels, test_labels = train_test_split(data_train, label_tain, test_size=0.5, random_state=42)

# %%
train_set.shape
# Out:
# (30000, 784)

# %%
train_labels.shape
# Out:
# (30000,)

# %% [markdown]
# # Try SVM models

# %%
model = GaussianNB()
model.fit(train_set, train_labels)
# Out:
# GaussianNB()

# %%
prediction = model.predict(test_set)

# %%
model.score(test_set, test_labels)
# Out:
# 0.5940333333333333

# %%
matrice = confusion_matrix(test_labels, prediction)

# %%
print(classification_report(test_labels, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.61      0.70      2974
#            1       0.68      0.94      0.79      2975
#            2       0.55      0.38      0.45      2999
#            3       0.45      0.65      0.53      2995
#            4       0.39      0.73      0.51      3039
#            5       0.88      0.26      0.40      2926
#            6       0.36      0.04      0.06      3034
#            7       0.50      0.98      0.67      3041
#            8       0.84      0.70      0.77      2996
#            9       0.92      0.65      0.76      3021
#
#     accuracy                           0.59     30000
#    macro avg       0.64      0.59      0.56     30000
# weighted avg       0.64      0.59      0.56     30000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(matrice, annot=True, fmt='d', cmap='plasma',
            xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Prédiction')
plt.ylabel('Réalité')
plt.title('Matrice de confusion')
plt.show()
